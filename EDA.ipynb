# %%
# Importamos las librerías pertinentes.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Importamos los archivos csv procesados en el ETL.
penetracion_provincial = pd.read_csv('archivos/archivos_eda/penetracion_eda.csv')
penetracion_nacional = pd.read_csv('archivos/archivos_eda/penetracion_nacional_eda.csv')
tecnologia = pd.read_csv('archivos/archivos_eda/tecnologia_eda.csv')
telefonia_fija = pd.read_csv('archivos/archivos_eda/telefonia_fija_eda.csv')
telefonia_movil = pd.read_csv('archivos/archivos_enacom/telefonia_movil.csv')
television_paga = pd.read_csv('archivos/archivos_eda/television_paga_eda.csv')
velocidad = pd.read_csv('archivos/archivos_eda/velocidad_eda.csv')

# %%
# Eliminamos la columna creada en la importación.
penetracion_provincial.drop('Unnamed: 0',axis=1,inplace=True)
penetracion_nacional.drop('Unnamed: 0',axis=1,inplace=True)
tecnologia.drop('Unnamed: 0',axis=1,inplace=True)
telefonia_fija.drop('Unnamed: 0',axis=1,inplace=True)
television_paga.drop('Unnamed: 0',axis=1,inplace=True)
velocidad.drop('Unnamed: 0',axis=1,inplace=True)

# %%
# Revertimos el orden de las columnas para darle una progresión de tiempo (pasado-futuro) a las visualizaciones.
penetracion_reversed = penetracion_provincial.iloc[::-1].reset_index()
penetracion_reversed.drop('index',axis=1,inplace=True)
penetracion_nacional_rev = penetracion_nacional.iloc[::-1].reset_index()
penetracion_nacional_rev.drop('index',axis=1,inplace=True)
tecnologia_rev = tecnologia.iloc[::-1].reset_index()
tecnologia_rev.drop('index',axis=1,inplace=True)
velocidad_rev = velocidad.iloc[::-1].reset_index()
velocidad_rev.drop('index',axis=1,inplace=True)
television_paga_rev = television_paga.iloc[::-1].reset_index()
television_paga_rev.drop('index',axis=1,inplace=True)

# %%
# Visualizamos el acceso a internet a nivel nacional.
plt.figure(figsize=(8,6))
plt.plot(penetracion_nacional_rev['Accesos por cada 100 hogares'],label='Accesos por cada 100 hogares')
plt.plot(penetracion_nacional_rev['Accesos por cada 100 hab'],label='Accesos por cada 100 habitantes')
plt.xticks([])
plt.xlabel('Años: 2014-2022')
plt.legend()
plt.title('Acceso a Internet')
# Out:
# Text(0.5, 1.0, 'Acceso a Internet')

# %%
# Visualizamos el acceso a internet en la región pampeana.
plt.figure(figsize=(8,6))
plt.plot(penetracion_reversed[penetracion_reversed['Provincia']=='Buenos Aires']['Accesos por cada 100 hogares'],label='Buenos Aires')
plt.plot(penetracion_reversed[penetracion_reversed['Provincia']=='Capital Federal']['Accesos por cada 100 hogares'],label='Capital Federal')
plt.plot(penetracion_reversed[penetracion_reversed['Provincia']=='Córdoba']['Accesos por cada 100 hogares'],label='Córdoba')
plt.plot(penetracion_reversed[penetracion_reversed['Provincia']=='Entre Ríos']['Accesos por cada 100 hogares'],label='Entre Ríos')
plt.plot(penetracion_reversed[penetracion_reversed['Provincia']=='La Pampa']['Accesos por cada 100 hogares'],label='La Pampa')
plt.plot(penetracion_reversed[penetracion_reversed['Provincia']=='Santa Fe']['Accesos por cada 100 hogares'],label='Santa Fe')
plt.title('Regíon Pampeana: accesos a Internet cada 100 personas')
plt.xlabel('Del Año 2014 al 2022')
plt.xticks([])
plt.legend()

# %% [markdown]
# Crecimiento muy similar en la región pampeana salvo en Capital Federal que se mantiene oscilando alrededor de 112%.

# %%
# Visualizamos el acceso a internet en la región del Cuyo.
plt.figure(figsize=(8,6))
plt.plot(penetracion_reversed[penetracion_reversed['Provincia']=='San Luis']['Accesos por cada 100 hogares'],linewidth=3,label='San Luis')
plt.plot(penetracion_reversed[penetracion_reversed['Provincia']=='San Juan']['Accesos por cada 100 hogares'],label='San Juan')
plt.plot(penetracion_reversed[penetracion_reversed['Provincia']=='Mendoza']['Accesos por cada 100 hogares'],label='Mendoza')
plt.title('Cuyo: accesos a Internet cada 100 personas')
plt.xlabel('Del Año 2014 al 2022')
plt.xticks([])
plt.legend()

# %% [markdown]
# Gran crecimiento en el acceso a internet en San Luis

# %%
# Visualizamos el acceso a internet en la región Noroeste.
plt.figure(figsize=(8,6))
plt.plot(penetracion_reversed[penetracion_reversed['Provincia']=='La Rioja']['Accesos por cada 100 hogares'],linewidth=3,label='La Rioja')
plt.plot(penetracion_reversed[penetracion_reversed['Provincia']=='Jujuy']['Accesos por cada 100 hogares'],label='Jujuy')
plt.plot(penetracion_reversed[penetracion_reversed['Provincia']=='Salta']['Accesos por cada 100 hogares'],label='Salta')
plt.plot(penetracion_reversed[penetracion_reversed['Provincia']=='Tucumán']['Accesos por cada 100 hogares'],label='Tucumán')
plt.plot(penetracion_reversed[penetracion_reversed['Provincia']=='Catamarca']['Accesos por cada 100 hogares'],label='Catamarca')
plt.plot(penetracion_reversed[penetracion_reversed['Provincia']=='Santiago Del Estero']['Accesos por cada 100 hogares'],label='Santiago Del Estero')
plt.title('Noroeste: accesos a Internet cada 100 personas')
plt.xlabel('Del Año 2014 al 2022')
plt.xticks([])
plt.legend()

# %% [markdown]
# Gran crecimiento en la penetración de La Rioja

# %%
# Visualizamos el acceso a internet en la Patagonia.
plt.figure(figsize=(8,6))
plt.plot(penetracion_reversed[penetracion_reversed['Provincia']=='Río Negro']['Accesos por cada 100 hogares'],label='Río Negro')
plt.plot(penetracion_reversed[penetracion_reversed['Provincia']=='Santa Cruz']['Accesos por cada 100 hogares'],label='Santa Cruz')
plt.plot(penetracion_reversed[penetracion_reversed['Provincia']=='Tierra Del Fuego']['Accesos por cada 100 hogares'],label='Tierra Del Fuego')
plt.title('Patagonia: accesos a Internet cada 100 personas')
plt.xlabel('Del Año 2014 al 2022')
plt.xticks([])
plt.legend()

# %% [markdown]
# Crecimiento similar en La Patagonia

# %%
# Visualizamos el acceso a internet en el Noreste.
plt.figure(figsize=(8,6))
plt.plot(penetracion_reversed[penetracion_reversed['Provincia']=='Formosa']['Accesos por cada 100 hogares'],label='Formosa')
plt.plot(penetracion_reversed[penetracion_reversed['Provincia']=='Corrientes']['Accesos por cada 100 hogares'],label='Corrientes')
plt.plot(penetracion_reversed[penetracion_reversed['Provincia']=='Chaco']['Accesos por cada 100 hogares'],label='Chaco')
plt.plot(penetracion_reversed[penetracion_reversed['Provincia']=='Misiones']['Accesos por cada 100 hogares'],label='Misiones')
plt.title('Noreste: accesos a Internet cada 100 personas')
plt.xlabel('Del Año 2014 al 2022')
plt.xticks([])
plt.legend()

# %% [markdown]
# Crecimiento similar en toda la región Noreste

# %%
# Seteamos los tamaños generales para las distinas etiquetas de las gráficas

SMALL_SIZE = 10
MEDIUM_SIZE = 15
BIGGER_SIZE = 30

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
#plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=SMALL_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)

# %% [markdown]
# TECNOLOGÍAS INTERNET EN ARGENTINA

# %%
# Visualizamos la evolución de las cuatro tecnologías más importantes de Internet a nivel nacional.
plt.figure(figsize=(10,6))
plt.plot(tecnologia_rev['Periodo'],tecnologia_rev['Fibra óptica'],label='Fibra optica')
plt.plot(tecnologia_rev['Cablemodem'],label='Cablemodem')
plt.plot(tecnologia_rev['Wireless'],label='Wireless')
plt.plot(tecnologia_rev['ADSL'],label='ADSL')
plt.xticks([])
plt.xlabel('Años:2014 a 2022')
plt.ylabel('Cantidad de Consumidores')
plt.legend()
plt.title('Evolución de Tecnologías en Argentina')
# Out:
# Text(0.5, 1.0, 'Evolución de Tecnologías en Argentina')

# %% [markdown]
# Tecnologías que incrementan sus consumidores: Fibra óptica y Cablemodem.

# %% [markdown]
# Tecnologías que disminuyen sus consumidores: ADSL.

# %% [markdown]
# Tecnologías que se mantienen igual: Wireless.

# %%
# Hacemos un mapa de correlación entre las tecnologías
sns.heatmap(tecnologia_rev[['ADSL','Cablemodem','Fibra óptica','Wireless']].corr())
# Out:
# <AxesSubplot: >

# %% [markdown]
# Vemos una alta correlación positiva entre Cablemodem y Fibra óptica, y a la vez, una alta correlación negativa de ambas tecnologías con ADSL.
# Estás correlaciones se pueden explicar por la creciente necesidad de mayor ancho de banda en la velocidad de bajada de los consumidores.

# %%
# Visualizamos el consumo de telefonía fija a nivel nacional.
plt.plot(telefonia_fija['Accesos telefonía fija (comercial)'],label='comercial')
plt.plot(telefonia_fija['Accesos telefonía fija (hogares)'],label='hogares')
plt.plot(telefonia_fija['Accesos telefonía fija (gobierno)'],label='gobierno')
plt.plot(telefonia_fija['Accesos telefonía fija (otros)'],label='otros')
plt.plot(telefonia_fija['Accesos telefonía fija (total)'],label='total')
plt.title('Consumo de Telefonía fija')
plt.xticks([])
plt.xlabel('Años: 2014 - 2022')
plt.ylabel('Cantidad de Consumidores')
plt.legend()

# %% [markdown]
# Vemos un consumo decreciente del año 2014 al año 2022 en el total y en la rama más importante(hogares). No así en el sector gubernamental ni en el comercial.

# %%
# Visualizamos la evolución del consumo de ADSL y Telefonía Fija a nivel nacional.
plt.figure(figsize=(8,6))
plt.plot(tecnologia_rev['ADSL'],label='ADSL')
plt.plot(telefonia_fija['Accesos telefonía fija (total)'],label='Telefonía Fija')
plt.legend()
plt.xticks([])
plt.title('Comparación entre el consumo de telefonía fija y el consumo de ADSL')
plt.xlabel('Del Año 2014 al 2022')
plt.ylabel('Cantidad de Consumidores')
# Out:
# Text(0, 0.5, 'Cantidad de Consumidores')

# %%
# Visualizamos la evolución de la velocidad de bajada media (Mbps) a nivel nacional.
plt.figure(figsize=(4,2))
plt.plot(velocidad_rev['Mbps (Media de bajada)'])
plt.xticks([])
plt.xlabel('Años: 2014 a 2022')
plt.title('Velocidad media de bajada: Mbps')
plt.ylabel('Mega Bits per second')
# Out:
# Text(0, 0.5, 'Mega Bits per second')

# %%
# Chequeamos niveles de correlación entre el consumo de la tecnología ADSL y el consumo de la telefonía fija.

np.corrcoef(tecnologia_rev['ADSL'].values,telefonia_fija['Accesos telefonía fija (total)'].values)
# Out:
# array([[ 1.        , -0.99266697],
#        [-0.99266697,  1.        ]])

# %%
# Chequeamos niveles de correlación entre el consumo de la tecnología ADSL y la velocidad media de bajada.

np.corrcoef(tecnologia_rev['ADSL'].values,velocidad_rev['Mbps (Media de bajada)'].values)
# Out:
# array([[ 1.        , -0.99266697],
#        [-0.99266697,  1.        ]])

# %% [markdown]
# Hay una correlación fuerte entre el consumo de la tecnología ADSL y el consumo de telefonía fija y tiene sentido porque la tecnología ADSL usa el cableado de la telefonía fija para enviar su señal, por ende, muchas operadoras de telefonía fija arman paquetes de promoción con Internet + Telefonía Fija.
#
# Vemos una correlación negativa muy fuerte entre el consumo de la tecnología ADSL y la velocidad media de bajada. Esto puede significar que, dado que la tecnología ADSL tiene un límite de velocidad de bajada situado en 24 Mbps, y las costumbres han ido llevándonos hacia el consumo de streaming(Netflix,Amazon Prime, Youtube,Spotify), el límite de la tecnología ADSL es muy bajo para las costumbres actuales.
# (Netflix recomienda (3Mbps para 720p, 5MBps para 1080p y 15Mbps para 4k) https://help.netflix.com/es/node/306)
#
# Si a eso le sumamos que el la vida actual pasa mucho por las redes sociales(Instagram, Facebook,Tik-tok,Twitter), y que los distintos dispositivos que consumen Internet se van sumando en el consumo simultáneo, se necesitan cada vez más velocidades más grandes de bajada.

# %%
# Visualizamos la evolución del consumo de TV por Suscripción y el consumo de Cablemodem a nivel nacional.
plt.figure(figsize=(8,6))
plt.plot(television_paga_rev['Accesos TV por suscripción'],label='TV Cable')
plt.plot(television_paga_rev['Accesos TV satelital'],label='TV Satelital')
plt.legend()
plt.xticks([])
plt.title('Televisión Paga en Argentina')
plt.xlabel('Años: 2014 al 2022')
plt.ylabel('Cantidad de Suscriptores')
# Out:
# Text(0, 0.5, 'Cantidad de Suscriptores')

# %% [markdown]
# El consumo de televisión por cable ha aumentado en los últimos 10 años, a diferencia del consumo de TV Satelital, que ha disminuido.

# %%
# Visualizamos la evolución del consumo de TV por Suscripción y el consumo de Cablemodem a nivel nacional.
plt.figure(figsize=(8,6))
plt.plot(television_paga_rev['Accesos TV por suscripción'],label='TV Cable')
plt.plot(tecnologia_rev['Cablemodem'],label='Cablemodem')
plt.legend()
plt.xticks([])
plt.title('Comparación entre el consumo de TV por Cable y el consumo de Cablemodem')
plt.xlabel('Del Año 2014 al 2022')
plt.ylabel('Cantidad de Suscriptores')
# Out:
# Text(0, 0.5, 'Cantidad de Suscriptores')

# %% [markdown]
# Por otro lado, al comparar el consumo de TV por cable y el consumo de la tecnología Cablemodem (sistemas de transferencia de datos que utilizan el mismo medio), podemos ver que si bien el consumo de TV por cable aumenta pero no muy fuertemente(mucha gente opta al día de hoy por bajarse y consumir directamente servicios de streaming on demand) muchos de esos consumidores han sumado el consumo de internet por Cablemodem.

# %%
# Visualizamos la evolución del consumo de telefonía móvil a nivel nacional del 2013 al 2022.
plt.figure(figsize=(10,8))
plt.plot(telefonia_movil['Accesos por cada 100 hab'])
plt.title('Acceso a un teléfono móvil por cada 100 habitantes')
plt.xticks([])
plt.xlabel('Años: 2013 a 2022')
# Out:
# Text(0.5, 0, 'Años: 2013 a 2022')

# %% [markdown]
# El consumo del teléfono móvil estaba en 160 por cada 100 habitantes en el 2013 y llegó a un piso de 120 en el 2020 (pandemia mundial).
